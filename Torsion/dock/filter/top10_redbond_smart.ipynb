# %%
import pandas as pd
input_file = open("/home/mxu02/dock37-test/test_dude/script/torsion/dock/filter/smiles_type.csv", 'r')
data = pd.read_csv(input_file, sep="\t", header=None, names=["Smart", "Number"])
data.tail(20)
# Out:
#                                                  Smart  Number
# 261               [!#1:1][CX3:2](=S)!@[NX3H1:3][!#1:4]    8152
# 262                     [cH0:1][c:2]!@[CX4H2:3][CX4:4]    8481
# 263     [O:1]=[CX3:2]([$([NX3H1]C)])!@[NX3H1:3][!#1:4]    9157
# 264                     [s:1][c:2]!@[C:3]([NH1])=[O:4]    9612
# 265                       [c:1][CX4H2:2]!@[OX2:3][c:4]   10060
# 266                       [*:1]~[NX3:2]!@[NX2:3]~[*:4]   10117
# 267  [OX2:1][CX4H2:2]!@[CX3:3]([$([NX3H1,NX3H2])])=...   10965
# 268                       N[C:2](=[O:1])!@[CH2:3][N:4]   11062
# 269                [aH1:1][c:2]([aH1])!@[SX4:3][!#1:4]   12263
# 270                 [$(C=O):1][NX3H1:2]!@[c:3](s)[n:4]   12776
# 271                    [cH1:1][c:2]([cH1])!@[O:3][C:4]   14652
# 272               [$([C](=O)):1][NX3:2]!@[a:3](s)[a:4]   15111
# 273                       [cH1,n:1][c:2]!@[O:3][CH1:4]   16368
# 274                       [!#1:1][CH2:2]!@[n:3][cH0:4]   16677
# ...

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol1 = Chem.MolFromSmarts("[cH1:1][c:2](cO)!@[O:3][C:4]")
mol1

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[cH0:1][c:2]([cH1])!@[O:3][C:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[$([c]([NH1,NH2])):1][c:2]!@[CX3:3]([!O])=[O:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[$(C=O):1][NX3H1:2]!@[c:3]([cH1])[cH1:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[O:1]=[C:2]!@[O:3]~[C:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[C:1][CX4H2:2]!@[OX2:3][c:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[!#1:1][CH2:2]!@[n:3][cH0:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[cH1,n:1][c:2]!@[O:3][CH1:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[$([C](=O)):1][NX3:2]!@[a:3](s)[a:4]")
mol

# %%
from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
mol = Chem.MolFromSmarts("[cH1:1][c:2]([cH1])!@[O:3][C:4]")
mol
