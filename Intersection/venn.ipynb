# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

with open("/home/mxu02/dock37-test/test_dude/script/intersection/intersection.csv",'r') as f:
# with open("/home/mxu02/dock37-test/test_dude/script/intersection/l",'r') as f:
    for line in f:
        target = line.split()[0]
        intersection = line.split()[1].split(":")[1]
        dock = line.split()[2].split(":")[1]
        vina = line.split()[3].split(":")[1]
        # print(target, intersection, dock, vina)
        # venn2(subsets = (106, 39, 25),set_labels = ('DOCK', 'Vina'))
        my_dpi=100
        plt.figure(figsize=(350/my_dpi, 350/my_dpi), dpi=my_dpi)
        venn2(subsets = (int(dock), int(vina), int(intersection)),set_labels = ('DOCK', 'Vina'))
        plt.title(f"Enriched actives (5%) of {target}")
# Out:
# /home/mxu02/miniconda3/envs/htmd/lib/python3.6/site-packages/matplotlib_venn/_venn2.py:50: UserWarning: Both circles have zero area
#   warnings.warn("Both circles have zero area")
# /home/mxu02/dock37-test/test_dude/script/intersection/intersection_venn.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   my_dpi=100
